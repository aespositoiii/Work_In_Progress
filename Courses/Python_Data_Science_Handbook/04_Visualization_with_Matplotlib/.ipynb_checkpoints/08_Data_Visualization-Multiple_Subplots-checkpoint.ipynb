# %% [markdown]
# # Multiple Subplots

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %% [markdown]
# ## 'plt.axes( )' : Subplots by Hand

# %%
ax1 = plt.axes() # standard axes

# plt.axes() takes an argument that can set the [ L, B, W, H]
# L = left edge offset of the subplot from the left edge of the window
# B = bottom edge offset of the subplot from the bottom edge of the window,
# W = Width from the left edge of the subplot to the right edge of the subplot
# H = Height from bottom edge of the subplot to the right edge of the subplot
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[],
                   xlim=(0, 10),
                   ylim=(-10, 10))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   xlim=(0, 10),
                   ylim=(-1.2, 1.2))

# %%
x = np.linspace(0,10,1000)
ax1.plot(x, (-.5*x)*np.sin(x**2))
ax2.plot(x, np.cos(x))
fig

# %% [markdown]
# ## plt.subplot( ) : Simple Grids of Subplots

# %%
n = 4
p = 4
for i in range(1, (n*p+1)):
    plt.subplot(n, p, i)
    plt.text(0.5, 0.5, str((n, p, i)),
             fontsize=18, ha='center')

# %%
# use plt.subplots_adjust() to set the distance between plots

n = 3
p = 3
fig = plt.figure()
fig.subplots_adjust(hspace=0.75, wspace=0.75)
for i in range(1, (n*p+1)):
    ax = fig.add_subplot(n, p, i)
    ax.text(0.5, 0.5, str((n, p, i)),
            fontsize=18, ha='center')

# %% [markdown]
# ## 'plt.subplots( )' : The Whole Grid in One Go

# %%
# Create a set of plots that share the same axis labels

fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
n = 4
p = 3

fig, ax = plt.subplots(n, p, sharex='col', sharey='row');

for i in range(n):
    for j in range(p):
        ax[i, j]. text(0.5, 0.5, str((i,j)),
                      fontsize=18, ha='center');

# %% [markdown]
# ## 'plt.GridSpec( )' : More Complicated Arrangements

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

# %%
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2])
# Out:
# <AxesSubplot:>

# %%
grid = plt.GridSpec(4, 4, wspace=0.4, hspace=0.3)

# %%
grid
# Out:
# GridSpec(4, 4)

# %%
plt.subplot(grid[:3,:3])
plt.subplot(grid[3, :])
plt.subplot(grid[:3, 3])
# Out:
# <AxesSubplot:>

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1,2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
           orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
           orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
import pandas as pd
import requests
import json
from bs4 import BeautifulSoup

# %%
url = "https://zillowdimashirokovv1.p.rapidapi.com/GetSearchResults.htm"

payload = "citystatezip=18055&zws-id=X1-ZWz16n8qjzse17_56tmg&rentzestimate=%5Btrue%2Cfalse%5D&address=1865%20Mill%20Run%20Ct"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'x-rapidapi-key': "b798a49d6cmsha387ce886e321c8p14c49fjsn25d8702bf78d",
    'x-rapidapi-host': "ZillowdimashirokovV1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?><SearchResults:searchresults xsi:schemaLocation="http://www.zillow.com/static/xsd/SearchResults.xsd https://www.zillowstatic.com/vstatic/80d5e73/static/xsd/SearchResults.xsd" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:SearchResults="http://www.zillow.com/static/xsd/SearchResults.xsd"><request><address></address><citystatezip></citystatezip></request><message><text>Error: this account is not authorized to execute this API call</text><code>6</code></message></SearchResults:searchresults><!-- H:003  T:7ms  S:150  R:Mon May 24 08:45:59 PDT 2021  B:5.0.67161-master.cdf6cf7~qa.9fd30300 -->

# %%
import requests

url = "https://zillowdimashirokovv1.p.rapidapi.com/GetChart.htm"

payload = "zpid=10170017&unit-type=dollar&zws-id=X1-ZWz16n8qjzse17_56tmg&chartDuration=%5B%221year%22%2C%225years%22%2C%2210years%22%5D"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'x-rapidapi-key': "b798a49d6cmsha387ce886e321c8p14c49fjsn25d8702bf78d",
    'x-rapidapi-host': "ZillowdimashirokovV1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html><html itemscope="" itemtype="http://schema.org/Organization" class="no-js zsg-theme-modernized null" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:product="http://ogp.me/ns/product#" >
# <head>
# <title>Gone - Zillow | Zillow</title><meta name="description" content="Find homes for sale, rentals, home values, mortgages, and more. Real estate info for practically every home in the U.S."></meta><meta name="author" content="Zillow, Inc."/><meta name="Copyright" content="Copyright (c) 2006-2021 Zillow, Inc."></meta><script>
#         window.appInfo = Object.assign(
#             typeof window.appInfo === 'object' ? window.appInfo : {},
#             {"@zillow/page-frame-content":"d4416830"}
#         );
#     </script><script>
#         window.CLIENT_PROFILER_CONFIG = window.CLIENT_PROFILER_CONFIG || {
#             staticDimensions: {
#                 ABDecisionToken: "VI6Cuhe0fVLh",
# ...

# %%
soup = BeautifulSoup(response.text, "xml")
soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html>
# <html class="no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#">
# <head>
# <title>Gone - Zillow | Zillow</title><meta content="Find homes for sale, rentals, home values, mortgages, and more. Real estate info for practically every home in the U.S." name="description"/><meta content="Zillow, Inc." name="author"/><meta content="Copyright (c) 2006-2021 Zillow, Inc." name="Copyright"/><script>
#         window.appInfo = Object.assign(
#             typeof window.appInfo === 'object' ? window.appInfo : {},
#             {"@zillow/page-frame-content":"d4416830"}
#         );
#     </script><script>
#         window.CLIENT_PROFILER_CONFIG = window.CLIENT_PROFILER_CONFIG || {
#             staticDimensions: {
# ...

# %%
content_dict = {
        "street": [soup.find('street').text],
        "city": [soup.find('city').text],
        "state": [soup.find('state').text],
        "zipcode": [soup.find('zipcode').text],
        "zpid": [soup.find('zpid').text],
        "home_details": [soup.find('homedetails').text],
        "graphsanddata": [soup.find('graphsanddata').text],
        "mapthishome": [soup.find('mapthishome').text],
        "comparables": [soup.find('comparables').text],
        "latitude": [soup.find('latitude').text],
        "longitude": [soup.find('longitude').text],
        "zestimate_amount": [soup.find('amount').text],
        "zestimate_last_updated": [soup.find('last-updated').text],
        "zestimate_value_change": [soup.find('valueChange').text],
        "zestimate_range_low": [soup.find('valuationRange').find('low').text],
        "zestimate_range_high": [soup.find('valuationRange').find('high').text]
    }
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c2c70065a568> in <module>
#       2
#       3 content_dict = {
# ----> 4         "street": [soup.find('street').text],
#       5         "city": [soup.find('city').text],
#       6         "state": [soup.find('state').text],
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import requests

url = "https://zillowdimashirokovv1.p.rapidapi.com/getZestimate.htm"

payload = "zws-Id=X1-ZWz16n8qjzse17_56tmg&zpid=10170017&rentzestimate=%5Btrue%2Cfalse%5D"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'x-rapidapi-key': "b798a49d6cmsha387ce886e321c8p14c49fjsn25d8702bf78d",
    'x-rapidapi-host': "ZillowdimashirokovV1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE HTML>
# <html>
#     <head>
#     </head>
#     <body>
#         <div id="zillow-error-page"></div><script id="__ERROR_DATA__" type="application/json">{"message": "Error 404 - page not found."}</script><script src="https://www.zillowstatic.com//static-error-pages/LIVE/overall-commons-792545460c.js"></script><script src="https://www.zillowstatic.com//static-error-pages/LIVE/error-page/app-317f8c03a6.js"></script>
#     </body>
# </html>

# %%
import pyzillow

# %%
from pyzillow.pyzillow import ZillowWrapper, GetDeepSearchResults
address = '1600 Pennsylvania Ave NW'
zipcode = '20006'
zillow_data = ZillowWrapper('X1-ZWz16n8qjzse17_56tmg')
deep_search_response = zillow_data.get_deep_search_results(address,zipcode)
result = GetDeepSearchResults(deep_search_response)
print(result.zillow_id)
# Out:
# ---------------------------------------------------------------------------
# ZillowError                               Traceback (most recent call last)
# <ipython-input-16-525763d53415> in <module>
#       3 zipcode = '20006'
#       4 zillow_data = ZillowWrapper('X1-ZWz16n8qjzse17_56tmg')
# ----> 5 deep_search_response = zillow_data.get_deep_search_results(address,zipcode)
#       6 result = GetDeepSearchResults(deep_search_response)
#       7 print(result.zillow_id)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyzillow/pyzillow.py in get_deep_search_results(self, address, zipcode, rentzestimate)
#      75             "zws-id": self.api_key,
#      76         }
# ---> 77         return self.get_data(url, params)
#      78
#      79     def get_updated_property_details(self, zpid: str):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyzillow/pyzillow.py in get_data(self, url, params)
#     131
#     132         if response.findall("message/code")[0].text != "0":
# ...

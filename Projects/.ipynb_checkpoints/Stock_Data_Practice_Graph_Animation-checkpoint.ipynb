# %%
from alpha_vantage.timeseries import TimeSeries
from pprint import pprint
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
fd = FundamentalData.

# %%
AlphaVantage_API_key = ''

ts = TimeSeries(key='ba', output_format='pandas')
data, meta_data = ts.get_daily_adjusted(symbol='spy', outputsize='full')

# %%
data, meta_data = ts.get

# %%
goog = pd.read_csv('/Users/anthonyesposito/Desktop/python_practice/Daily_Stock_Prices/data/GOOG/GOOGrawDat.csv')

# %%
goog.head()
# Out:
#          date  1. open  2. high  3. low  4. close  5. volume
# 0  2014-03-27  568.000   568.00  552.92    558.46    13100.0
# 1  2014-03-28  561.200   566.43  558.67    559.99    41100.0
# 2  2014-03-31  566.890   567.00  556.93    556.97    10800.0
# 3  2014-04-01  558.710   568.45  558.71    567.16     7900.0
# 4  2014-04-02  565.106   604.83  562.19    567.00   146700.0

# %%
goog['date'].dtype
# Out:
# dtype('O')

# %%
goog['date']  = pd.to_datetime(goog['date'], yearfirst=True)

# %%
goog['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
goog.head()
# Out:
#         date  1. open  2. high  3. low  4. close  5. volume
# 0 2014-03-27  568.000   568.00  552.92    558.46    13100.0
# 1 2014-03-28  561.200   566.43  558.67    559.99    41100.0
# 2 2014-03-31  566.890   567.00  556.93    556.97    10800.0
# 3 2014-04-01  558.710   568.45  558.71    567.16     7900.0
# 4 2014-04-02  565.106   604.83  562.19    567.00   146700.0

# %%
goog = goog.set_index('date')

# %%
goog.head()
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2014-03-27  568.000   568.00  552.92    558.46    13100.0
# 2014-03-28  561.200   566.43  558.67    559.99    41100.0
# 2014-03-31  566.890   567.00  556.93    556.97    10800.0
# 2014-04-01  558.710   568.45  558.71    567.16     7900.0
# 2014-04-02  565.106   604.83  562.19    567.00   146700.0

# %%
plt.plot(goog.loc['2018','1. open'])

# %%
a = goog.rolling(2).mean()

# %%
b = a.diff(1)

# %%
plt.plot(a.loc['2015-1':'2015-6', '1. open':'4. close'])
# Out:
# [<matplotlib.lines.Line2D at 0x7febe9d1e8d0>,
#  <matplotlib.lines.Line2D at 0x7febe9d2d190>,
#  <matplotlib.lines.Line2D at 0x7febe9d39910>,
#  <matplotlib.lines.Line2D at 0x7febe9d39890>]

# %%
plt.plot(b.loc['2015-1':'2015-6', '1. open':'4. close'])
# Out:
# [<matplotlib.lines.Line2D at 0x7febea2a6a50>,
#  <matplotlib.lines.Line2D at 0x7febec1883d0>,
#  <matplotlib.lines.Line2D at 0x7febec1a1910>,
#  <matplotlib.lines.Line2D at 0x7febec1a1890>]

# %%
print(data.head(), '\n\n', data.tail())
# Out:
#             1. open   2. high   3. low  4. close  5. volume
# date
# 2021-02-26   122.93  123.5094  120.645    122.07  1902721.0
# 2021-02-25   124.81  125.2500  121.930    122.10  1425040.0
# 2021-02-24   122.26  125.4100  122.010    125.02  1898362.0
# 2021-02-23   123.51  123.5100  120.410    122.42  2125365.0
# 2021-02-22   125.95  126.1600  123.090    123.50  1335940.0
#
#              1. open  2. high  3. low  4. close   5. volume
# date
# 1999-11-24    40.13    41.94   40.00     41.06   3464400.0
# 1999-11-23    42.50    43.63   40.25     40.25   4274400.0
# 1999-11-22    41.31    44.00   40.06     44.00   4705200.0
# 1999-11-19    42.94    43.00   39.81     40.38  10897100.0
# 1999-11-18    45.50    50.00   40.00     44.00  44739900.0

# %%
print(meta_data)
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'A', '3. Last Refreshed': '2021-02-26', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}

# %%
def stockFFT(data, RollTS, RollFS, winMin, winMax, T0, T1):
    from scipy.fft import fft, fftfreq
    from datetime import date, timedelta

    from scipy.fft import fft, fftfreq

    data.index  = pd.to_datetime(data.index, yearfirst=True)

    data = data.sort_index()
    a = data.rolling(RollTS).mean()
    b = a.diff(1)
    b = b.loc[ T0:T1 , :]
    N = b['1. open'].dropna().shape[0]
    y = b['1. open'].dropna().values
    yf = fft(y)
    xf = fftfreq(N, 1/N)

    yfreal = yf.real
    yfimag = yf.imag
    yfmag = ( yfreal**2 + yfimag**2 ) ** .5

    yf = np.array([ yfreal, yfimag, yfmag]).T

    datafft = pd.DataFrame(yf, index=xf, columns=['Real', 'Imag', 'Prod'])
    datafft = datafft.sort_index()

    fig = plt.figure()
    ax1 = fig.add_axes([0.1, 0.6, 0.8, 0.4])
    ax1.plot(datafft.rolling(RollFS, center=True).mean().loc[max(0, winMin):min(datafft.index.max(), winMax)]);

# %%
def retrieveTS(sym):
    ts = TimeSeries(key='ba', output_format='pandas')
    data, meta_data = ts.get_daily_adjusted(symbol=sym, outputsize='full')
    data.index = pd.to_datetime(data.index)
    data = data.sort_index()
    return data, meta_data

# %%
def stockFFTdata(data, RollTS, RollFS, winMin, winMax, T0, T1):
    from scipy.fft import fft, fftfreq
    from datetime import date, timedelta

    from scipy.fft import fft, fftfreq

    data.index  = pd.to_datetime(data.index, yearfirst=True)

    data = data.sort_index()
    a = data.rolling(RollTS).mean()
    b = a.diff(1)
    b = b.loc[ T0:T1 , :]
    N = b['1. open'].dropna().shape[0]
    y = b['1. open'].dropna().values
    yf = fft(y)
    xf = fftfreq(N, 1/N)

    yfreal = yf.real
    yfimag = yf.imag
    yfmag = ( yfreal**2 + yfimag**2 ) ** .5

    yf = np.array([ yfreal, yfimag, yfmag]).T

    datafft = pd.DataFrame(yf, index=xf, columns=['Real', 'Imag', 'Prod'])
    datafft = datafft.sort_index()
    datafft = datafft.loc[winMin:winMax]
    
    return datafft

# %%
from datetime import date, timedelta

RollTS = 1
RollFS = 5
winMin = 10
winMax = 100
year = 365.25
T0 = date(2000, 2, 10)
dT = timedelta(days=(3 * year))
T1 = T0 + dT
T1 = date(2020, 2, 1)

from scipy.fft import fft, fftfreq

data.index  = pd.to_datetime(data.index, yearfirst=True)

data = data.sort_index()
a = data.rolling(RollTS).mean()
b = a.diff(1)
b = b.loc[ T0:T1 , :]
N = b['1. open'].dropna().shape[0]
y = b['1. open'].dropna().values
yf = fft(y)
xf = fftfreq(N, 1/N)

yfreal = yf.real
yfimag = yf.imag
yfmag = ( yfreal**2 + yfimag**2 ) ** .5
print(yfmag)

yf = np.array([ yfreal, yfimag, yfmag]).T

datafft = pd.DataFrame(yf, index=xf, columns=['Real', 'Imag', 'Prod'])
datafft = datafft.sort_index()

fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.6, 0.8, 0.4])
ax1.plot(datafft.rolling(RollFS, center=True).mean().loc[max(0, winMin):min(datafft.index.max(), winMax)]);
# Out:
# [124.32       106.66792091 119.01657032 ...  87.29523985 119.01657032
#  106.66792091]

# %%
stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 1, 1), T1=date(2020, 2, 10))

# %%
stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 2, 1), T1=date(2020, 2, 10))
# Out:
# [195.4175     132.92603183  50.41913073 ... 169.95179586  50.41913073
#  132.92603183]

# %%
stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 3, 1), T1=date(2020, 2, 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-478-43518cd35591> in <module>
# ----> 1 stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 3, 1), T1=date(2020, 2, 10))
#
# <ipython-input-477-7d5bb42311b6> in stockFFT(data, RollTS, RollFS, winMin, winMax, T0, T1)
#      31
#      32     fig = plt.figure()
# ---> 33     ax1 = fig.axes()
#      34     ax1.plot(datafft.rolling(RollFS, center=True).mean().loc[max(0, winMin):min(datafft.index.max(), winMax)]);
#
# TypeError: 'list' object is not callable

# %%
stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 4, 1), T1=date(2020, 2, 10))
# Out:
# [181.605      127.3683688   61.36835168 ... 164.56978592  61.36835168
#  127.3683688 ]

# %%
datafft = stockFFTdata(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 5, 1), T1=date(2020, 2, 10))

# %%
print(type(datafft.index))
# Out:
# <class 'pandas.core.indexes.numeric.Float64Index'>

# %%
datafft
# Out:
#             Real        Imag        Prod
# 10.0  -28.325925   95.258999   99.381260
# 11.0   78.498668   65.610850  102.307500
# 12.0   -1.363204   97.786494   97.795995
# 13.0   74.165116   40.566407   84.534595
# 14.0  -74.656763  -18.434500   76.899045
# ...          ...         ...         ...
# 96.0   94.094651  134.756694  164.356838
# 97.0   34.139839   21.076783   40.121807
# 98.0  -46.862723  -50.994812   69.257387
# 99.0   39.293561   48.187056   62.176976
# 100.0 -48.735475   83.096892   96.334002
#
# [91 rows x 3 columns]

# %%
fig = plt.figure()
ax = plt.axes()
line = ax.plot( datafft, lw=1)

# %%
stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 6, 1), T1=date(2020, 2, 10))
# Out:
# [188.6675     126.63464986  52.49504429 ... 161.01275097  52.49504429
#  126.63464986]

# %%
stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 7, 1), T1=date(2020, 2, 10))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-476-ebf2236775aa> in <module>
# ----> 1 stockFFT(data, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=date(2000, 7, 1), T1=date(2020, 2, 10))
#
# <ipython-input-475-052a54e5f250> in stockFFT(data, RollTS, RollFS, winMin, winMax, T0, T1)
#      31
#      32     fig = plt.figure()
# ---> 33     ax1 = fig.axes([0.1, 0.6, 0.8, 0.4])
#      34     ax1.plot(datafft.rolling(RollFS, center=True).mean().loc[max(0, winMin):min(datafft.index.max(), winMax)]);
#
# TypeError: 'list' object is not callable

# %%
import time

T=date(2000, 7, 1)
fig = plt.figure()
for i in range(10):
    T = T + timedelta(days=10)
    stockFFT(spy, RollTS=1, RollFS=5, winMin=10, winMax=100, T0=T, T1=date(2020, 2, 10))

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('classic')

# %%
my_dpi = 100
fig = plt.figure(figsize=(1200/my_dpi, 400/my_dpi), dpi=my_dpi)
ax = plt.axes(xlim = (0,100), ylim=(-300, 300))
line1, = ax.plot([], [], lw=1)
line2, = ax.plot([], [], lw=1)
line3, = ax.plot([], [], lw=1)

def init():
    line.set_data( [], [])
    return line,
def animate(i):
    y = stockFFTdata(spy, RollTS=1, RollFS=20, winMin=10, winMax=100, T0=(date(2000, 4, 1) + timedelta(days=i)), T1=date(2020, 2, 10))
    line1.set_data( y.index.values, y.iloc[:, 0].values)
    line2.set_data( y.index.values, y.iloc[:, 1].values)
    line3.set_data( y.index.values, y.iloc[:, 2].values)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=500, interval=20, blit=True)
anim.save('sine_wave.gif', writer='Pillow')
# Out:
# MovieWriter Pillow unavailable; using Pillow instead.

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes()
line, = ax.plot([], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


anim.save('sine_wave.gif', writer='Pillow')
# Out:
# MovieWriter Pillow unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1156                     # TODO: See if turning off blit is really necessary
# -> 1157                     anim._draw_next_frame(d, blit=False)
#    1158                     if progress_callback is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1191         self._pre_draw(framedata, blit)
# -> 1192         self._draw_frame(framedata)
#    1193         self._post_draw(framedata, blit)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_frame(self, framedata)
#    1741         # func needs to return a sequence of any artists that were modified.
# -> 1742         self._drawn_artists = self._func(framedata, *self._args)
#    1743         if self._blit:
#
# <ipython-input-553-539a4e785d6e> in animate(i)
#      16     y = np.sin(2 * np.pi * (x - 0.01 * i))
# ---> 17     line.set_data(y)
#      18     return line,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in set_data(self, *args)
#     639         if len(args) == 1:
# --> 640             (x, y), = args
#     641         else:
#
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-553-539a4e785d6e> in <module>
#      22
#      23
# ---> 24 anim.save('sine_wave.gif', writer='Pillow')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1159                         progress_callback(frame_number, total_frames)
#    1160                         frame_number += 1
# -> 1161                 writer.grab_frame(**savefig_kwargs)
#    1162
#    1163     def _step(self, *args):
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in finish(self)
#     552
#     553     def finish(self):
# --> 554         self._frames[0].save(
#     555             self.outfile, save_all=True, append_images=self._frames[1:],
#     556             duration=int(1000 / self.fps), loop=0)
#
# IndexError: list index out of range

# %%
goog, goog_meta = retrieveTS('GOOG')

# %%
spy, spy_meta = retrieveTS('SPY')

# %%
plt.plot(spy.loc['2010':'2019', '1. open':'4. close'])
# Out:
# [<matplotlib.lines.Line2D at 0x7febd6514fd0>,
#  <matplotlib.lines.Line2D at 0x7febd77322d0>,
#  <matplotlib.lines.Line2D at 0x7febd772ef50>,
#  <matplotlib.lines.Line2D at 0x7febd770a0d0>]

# %%
plt.plot(goog.loc['2010':'2019', '1. open':'4. close'])
# Out:
# [<matplotlib.lines.Line2D at 0x7febd8b89b10>,
#  <matplotlib.lines.Line2D at 0x7febda7d3e90>,
#  <matplotlib.lines.Line2D at 0x7febd7733550>,
#  <matplotlib.lines.Line2D at 0x7feb85431950>]

# %%
combinedData = pd.DataFrame([goog['1. open'], spy['1. open']])

# %%
combinedData = pd.DataFrame([goog['1. open'], spy['1. open']])
combinedData = combinedData.T
combinedData = combinedData.dropna()
combinedDatadiff = combinedData.diff(1, axis=0)
combinedDatadiff = combinedDatadiff/combinedData
combinedDatadiff = combinedDatadiff.dropna()
combinedDatadiff.iloc[:,1]
# Out:
# date
# 2014-03-28    0.001945
# 2014-03-31    0.008357
# 2014-04-01    0.005063
# 2014-04-02    0.004616
# 2014-04-03    0.003595
#                 ...
# 2021-02-23   -0.006239
# 2021-02-24    0.004323
# 2021-02-25    0.010451
# 2021-02-26   -0.015767
# 2021-03-01    0.003216
# Name: 1. open, Length: 1743, dtype: float64

# %%
plt.xcorr(combinedDatadiff.iloc[:,0], combinedDatadiff.iloc[:,1], normed=True, maxlags=None)
# Out:
# (array([-1742, -1741, -1740, ...,  1740,  1741,  1742]),
#  array([-1.26589300e-04,  7.25512340e-04, -1.07846080e-03, ...,
#         -9.78712097e-05,  2.70451295e-05,  1.84332010e-05]),
#  <matplotlib.collections.LineCollection at 0x7febdb710150>,
#  <matplotlib.lines.Line2D at 0x7febdb710090>)
